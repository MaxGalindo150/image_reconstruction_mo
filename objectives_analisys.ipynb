# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("results_pareto_single_value.csv")

# %%
results_df
# Out:
#            lambda        f1            f2        f3
# 0    1.096619e+02  1.000000  0.000000e+00  0.000000
# 1    4.643872e-12  0.000000  1.000000e+00  1.000000
# 2    1.582810e+02  1.000000  0.000000e+00  0.000000
# 3    1.308633e-11  0.000000  1.000000e+00  1.000000
# 4    4.475214e-08  0.002193  3.580810e-01  0.597167
# ..            ...       ...           ...       ...
# 495  8.402398e-03  0.579521  1.761117e-06  0.000658
# 496  1.108284e-01  0.942944  2.356021e-08  0.000092
# 497  3.553323e-08  0.017122  5.205260e-03  0.070245
# 498  1.930541e-04  0.094193  3.331954e-05  0.001536
# 499  2.774477e-03  0.346738  6.226729e-06  0.000946
#
# [500 rows x 4 columns]

# %%
# Assuming `results_df` is already loaded
correlation_matrix = results_df[["f1", "f2", "f3"]].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Matrix of Objectives")
plt.show()

# %%
# Load your objectives
objectives = results_df[['f1', 'f2', 'f3']]

# Pairwise scatterplots
sns.pairplot(objectives, diag_kind="kde", markers="o", plot_kws={'alpha': 0.6})
plt.suptitle("Pairwise Scatterplots of Objectives", y=1.02, fontsize=16)
plt.savefig("pairwise_objectives.png")
plt.show()
