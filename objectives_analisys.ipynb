# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("results_pareto_single_value.csv")

# %%
results_df
# Out:
#            lambda            f1        f2        f3
# 0    3.254135e+02  1.000000e+00  0.000000  0.000000
# 1    3.365778e-03  0.000000e+00  1.000000  0.000000
# 2    1.101644e-13  4.426217e-13  0.999999  1.000000
# 3    2.979617e+02  1.000000e+00  0.000000  0.000000
# 4    1.229768e-04  0.000000e+00  1.000000  0.000000
# ..            ...           ...       ...       ...
# 495  2.697475e-03  3.990813e-01  0.000011  0.000000
# 496  1.922165e-09  2.950436e-03  0.239624  0.503025
# 497  1.100773e-03  2.364857e-01  0.000026  0.000000
# 498  1.611304e-03  2.984169e-01  0.000019  0.000000
# 499  6.095429e-10  7.404156e-04  0.549860  0.751494
#
# [500 rows x 4 columns]

# %%
# Assuming `results_df` is already loaded
correlation_matrix = results_df[["f1", "f2", "f3"]].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Matrix of Objectives")
plt.show()

# %%
# Load your objectives
objectives = results_df[['f1', 'f2', 'f3']]

# Pairwise scatterplots
sns.pairplot(objectives, diag_kind="kde", markers="o", plot_kws={'alpha': 0.6})
plt.suptitle("Pairwise Scatterplots of Objectives", y=1.02, fontsize=16)
plt.savefig("pairwise_objectives.png")
plt.show()
