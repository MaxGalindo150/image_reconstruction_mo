# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("results_pareto_single_value.csv")

# %%
results_df
# Out:
#            lambda            f1        f2        f3
# 0    1.651885e+02  1.000000e+00  0.000000  0.000000
# 1    9.972573e+01  1.000000e+00  0.000000  0.000000
# 2    5.105739e-04  0.000000e+00  1.000000  0.952473
# 3    1.193848e-07  1.508386e-07  0.999881  0.999939
# 4    1.163289e-07  2.371092e-04  0.821092  0.911682
# ..            ...           ...       ...       ...
# 495  3.095874e-06  1.211617e-02  0.004652  0.048826
# 496  9.602296e-07  1.634607e-02  0.001319  0.031530
# 497  5.164055e-06  1.454878e-02  0.003362  0.035337
# 498  3.187926e-06  1.538971e-02  0.001890  0.030625
# 499  8.129221e-07  1.606208e-02  0.001422  0.033334
#
# [500 rows x 4 columns]

# %%
correlation_matrix = results_df[["f1", "f2", "f3"]].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Matrix of Objectives")
plt.show()

# %%
objectives = results_df[['f1', 'f2', 'f3']]

sns.pairplot(objectives, diag_kind="kde", markers="o", plot_kws={'alpha': 0.6})
plt.suptitle("Pairwise Scatterplots of Objectives", y=1.02, fontsize=16)
plt.savefig("pairwise_objectives.png")
plt.show()
