# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("solutions_comparison.csv")

# %%
results_df
# Out:
#                  Solution Type        lambda        f1        f2        f3  \
# 0             L-Curve Solution  6.977709e-06  0.000160  0.024778  0.006687
# 1                Best Solution  2.056781e-05  0.000338  0.023932  0.004173
# 2      Pareto Front Solution 0  1.756031e+02  1.000000  0.000000  0.000000
# 3      Pareto Front Solution 1  1.119375e+02  1.000000  0.000000  0.000000
# 4      Pareto Front Solution 2  1.186251e-04  0.000000  1.000000  0.140968
# ..                         ...           ...       ...       ...       ...
# 497  Pareto Front Solution 495  6.533045e-03  0.428315  0.001933  0.018346
# 498  Pareto Front Solution 496  8.684920e-10  0.000003  0.466670  0.642206
# 499  Pareto Front Solution 497  1.964745e-08  0.000023  0.059453  0.111698
# 500  Pareto Front Solution 498  1.325684e-02  0.608136  0.000748  0.014049
# 501  Pareto Front Solution 499  1.027936e-02  0.544594  0.001073  0.015873
#
#      Index in Pareto Front
# 0                      NaN
# 1                    322.0
# 2                      0.0
# 3                      1.0
# 4                      2.0
# ..                     ...
# 497                  495.0
# 498                  496.0
# 499                  497.0
# 500                  498.0
# 501                  499.0
#
# [502 rows x 6 columns]

# %%
correlation_matrix = results_df[["f1", "f2", "f3"]].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Matrix of Objectives")
plt.show()

# %%
objectives = results_df[['f1', 'f2', 'f3']]

sns.pairplot(objectives, diag_kind="kde", markers="o", plot_kws={'alpha': 0.6})
plt.suptitle("Pairwise Scatterplots of Objectives", y=1.02, fontsize=16)
plt.savefig("pairwise_objectives.png")
plt.show()
