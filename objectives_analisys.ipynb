# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("solutions_comparison_moead.csv")

# %%
results_df
# Out:
#                  Solution Type    lambda        f1        f2        f3  \
# 0             L-Curve Solution  0.000014  0.000000  1.000000  0.000000
# 1                Best Solution  0.001393  0.000000  1.000000  0.347473
# 2      Pareto Front Solution 0  0.022952  0.706103  0.037516  0.559833
# 3      Pareto Front Solution 1  0.365364  0.984280  0.000185  0.031052
# 4      Pareto Front Solution 2  0.461193  0.989383  0.000106  0.020979
# ..                         ...       ...       ...       ...       ...
# 493  Pareto Front Solution 491  0.279946  0.976866  0.000332  0.045678
# 494  Pareto Front Solution 492  0.507151  0.991156  0.000083  0.017476
# 495  Pareto Front Solution 493  0.508098  0.991189  0.000082  0.017411
# 496  Pareto Front Solution 494  0.131367  0.942274  0.001546  0.113716
# 497  Pareto Front Solution 495  0.431425  0.988036  0.000125  0.023638
#
#      Index in Pareto Front
# 0                      NaN
# 1                     76.0
# 2                      0.0
# ...

# %%
correlation_matrix = results_df[["f1", "f2", "f3"]].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Matiz de correlación entre las funciones objetivo")
plt.show()

# %%
objectives = results_df[['f1', 'f2', 'f3']]

pairplot = sns.pairplot(objectives, diag_kind="kde", markers="o", plot_kws={'alpha': 0.6})

pairplot.fig.suptitle("Diagramas de Dispersión por Pares de Objetivos", y=1.02, fontsize=16)
pairplot.fig.tight_layout()

plt.savefig("pairwise_objectives.png", dpi=300, bbox_inches="tight")
plt.show()
